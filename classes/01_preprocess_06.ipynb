# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('https://raw.githubusercontent.com/mariolpantunes/ml101/main/datasets/housing.csv')

# %%
data = pd.get_dummies(data)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data.drop(['SalePrice'], axis=1), 
                                                    data.SalePrice, test_size=0.3, 
                                                    random_state=0)

# %% [markdown]
# # Recursive Feature Elimination

# %%
from sklearn.feature_selection import RFECV

# use any other model you want here.
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=411)

# build the RFE with CV option.
rfe = RFECV(model, min_features_to_select = 3, step = 1 , cv=5, scoring='accuracy')

# %%
# fit the RFE to our data.
selection  = rfe.fit(x_train, y_train)

# print the selected features.
print(x_train.columns[selection.support_])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-db760f84e8a8> in <module>()
#       1 # fit the RFE to our data.
# ----> 2 selection  = rfe.fit(x_train, y_train)
#       3
#       4 # print the selected features.
#       5 print(x_train.columns[selection.support_])
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_rfe.py in fit(self, X, y, groups)
#     710         scores = parallel(
#     711             func(rfe, self.estimator, X, y, train, test, scorer)
# --> 712             for train, test in cv.split(X, y, groups)
#     713         )
#     714
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_rfe.py in <genexpr>(.0)
#     710         scores = parallel(
#     711             func(rfe, self.estimator, X, y, train, test, scorer)
# --> 712             for train, test in cv.split(X, y, groups)
#     713         )
#     714
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_rfe.py in _rfe_single_fit(rfe, estimator, X, y, train, test, scorer)
#      38         X_train,
#      39         y_train,
# ---> 40         lambda estimator, features: _score(
#      41             estimator, X_test[:, features], y_test, scorer
#      42         ),
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_rfe.py in _fit(self, X, y, step_score, **fit_params)
#     301             # that have not been eliminated yet
#     302             if step_score:
# --> 303                 self.scores_.append(step_score(estimator, features))
#     304             support_[features[ranks][:threshold]] = False
#     305             ranking_[np.logical_not(support_)] += 1
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_rfe.py in <lambda>(estimator, features)
#      39         y_train,
#      40         lambda estimator, features: _score(
# ---> 41             estimator, X_test[:, features], y_test, scorer
#      42         ),
#      43     ).scores_
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py in _score(estimator, X_test, y_test, scorer, error_score)
#     759             scores = scorer(estimator, X_test)
#     760         else:
# --> 761             scores = scorer(estimator, X_test, y_test)
#     762     except Exception:
#     763         if error_score == "raise":
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_scorer.py in __call__(self, estimator, X, y_true, sample_weight)
#     219             X,
#     220             y_true,
# --> 221             sample_weight=sample_weight,
#     222         )
#     223
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_scorer.py in _score(self, method_caller, estimator, X, y_true, sample_weight)
#     262             )
#     263         else:
# --> 264             return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#     265
#     266
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     209
#     210     # Compute accuracy for each possible representation
# --> 211     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212     check_consistent_length(y_true, y_pred, sample_weight)
#     213     if y_type.startswith("multilabel"):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      93         raise ValueError(
#      94             "Classification metrics can't handle a mix of {0} and {1} targets".format(
# ---> 95                 type_true, type_pred
#      96             )
#      97         )
#
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets

# %% [markdown]
# # Recursive Feature Addition

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error 

# array to hold the feature to be keept.
features_to_keep = [x_train.columns[0]]

# set this value according to you.
threshold = 0.002

# create your prefered model and  fit it to the training data.
model_one_feature = RandomForestRegressor(n_estimators=332)
model_one_feature.fit(x_train[[x_train.columns[0]]], y_train)

# evaluate against your metric.
y_pred_test = model_one_feature.predict(x_test[[x_train.columns[0]]])
mse_score_all = mean_squared_error(y_test, y_pred_test)

# %%
# start iterating from the feature.
for feature in x_train.columns[1:]:
    
    model = RandomForestRegressor(n_estimators=332)
    
    # fit model with  the selected features and the feature to be evaluated
    model.fit(x_train[features_to_keep + [feature]], y_train)
    y_pred_test = model.predict(x_test[features_to_keep + [feature]])
    mse_score_int = mean_squared_error(y_test, y_pred_test)

    # determine the drop in the roc-auc
    diff_auc = mse_score_int - mse_score_all

    # compare the drop in roc-auc with the threshold
    if diff_auc >= threshold:
        
        # if the increase in the roc is bigger than the threshold
        # we keep the feature and re-adjust the roc-auc to the new value
        # considering the added feature
        mse_score_all = amse_score_int
        features_to_keep.append(feature)

# %%
# print the feature to keep.
print(features_to_keep)
